# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nltk
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 4.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.6 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.6 MB/s  0:00:00
# Installing collected packages: nltk
# Successfully installed nltk-3.9.4
#   WARNING: The script nltk.exe is installed in 'C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import nltk
import string
from nltk.tokenize import work_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import nltk
#       2 import string
# ----> 3 from nltk.tokenize import work_tokenize
#       4 from nltk.corpus import stopwords
#       5 from nltk.stem import PorterStemmer, WordNetLemmatizer
#
# ImportError: cannot import name 'work_tokenize' from 'nltk.tokenize' (C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\nltk\tokenize\__init__.py)

# %%
nltk.download(['punkt','punk_tab','stopwords','wordnet'])
