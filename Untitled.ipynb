# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 4.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.6 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.6 MB/s  0:00:00
# ...
#   WARNING: The script nltk.exe is installed in 'C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
nltk.download(['punkt','punkt_tab','stopwords','wordnet'])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# True

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
text="Natural Language Processing (NLP) is transforming how computers understand human language"

# %%
text=text.lower()
print("Lowercased:",text)
# Out:
# Lowercased: natural language processing (nlp) is transforming how computers understand human language

# %%
tokens=word_tokenize(text)
print("Tokens:",tokens)
# Out:
# Tokens: ['natural', 'language', 'processing', '(', 'nlp', ')', 'is', 'transforming', 'how', 'computers', 'understand', 'human', 'language']

# %%
tokens=[t for t in tokens if t not in string.punctuation]
print("no punctuation:",tokens)
# Out:
# no punctuation: ['natural', 'language', 'processing', 'nlp', 'is', 'transforming', 'how', 'computers', 'understand', 'human', 'language']

# %%
stop_words=set(stopwords.words('english'))
tokens=[t for t in tokens if t not in stop_words]
print("No stopwords:",tokens)
# Out:
# No stopwords: ['natural', 'language', 'processing', 'nlp', 'transforming', 'computers', 'understand', 'human', 'language']

# %%
stemmer=PorterStemmer()
stemmed=[stemmer.stem(t) for t in tokens]
print("Stemmed:",stemmed)
# Out:
# Stemmed: ['natur', 'languag', 'process', 'nlp', 'transform', 'comput', 'understand', 'human', 'languag']

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(t) for t in tokens]

print("Lemmatized:", lemmatized)
# Out:
# Lemmatized: ['natural', 'language', 'processing', 'nlp', 'transforming', 'computer', 'understand', 'human', 'language']
